# %% [markdown]
# # Day 02: Statistical Learning with scikit-learn

# %% [markdown]
# Welcome to practical 2! Linear models, regularization, and classification on built-in datasets.
#
# Work through each exercise in order. Look for `# YOUR CODE HERE` markers — replace the reference implementations with your own solutions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression, load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

np.random.seed(42)

# %% [markdown]
# ### Exercise 2.1: Linear regression baseline

# %% [markdown]
# **Your job**: Fit `LinearRegression` on synthetic data and report train/test MSE.

# %%
X, y = make_regression(n_samples=200, n_features=5, noise=4.0, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# YOUR CODE HERE
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test MSE:", mean_squared_error(y_test, y_pred))

# %% [markdown]
# ### Exercise 2.2: Ridge regression

# %% [markdown]
# **Your job**: Compare Ridge ($\alpha=1$) vs OLS on the same split.

# %%
# YOUR CODE HERE
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
print("Ridge test MSE:", mean_squared_error(y_test, ridge.predict(X_test)))
print("OLS  test MSE:", mean_squared_error(y_test, model.predict(X_test)))

# %% [markdown]
# ### Exercise 2.3: Logistic regression

# %% [markdown]
# **Your job**: Train a classifier on Breast Cancer Wisconsin and report accuracy.

# %%
data = load_breast_cancer()
Xc, yc = data.data, data.target
Xc_tr, Xc_te, yc_tr, yc_te = train_test_split(Xc, yc, test_size=0.25, random_state=0, stratify=yc)

# YOUR CODE HERE
clf = Pipeline([
    ("scaler", StandardScaler()),
    ("logreg", LogisticRegression(max_iter=1000)),
])
clf.fit(Xc_tr, yc_tr)
yc_pred = clf.predict(Xc_te)
print("Accuracy:", accuracy_score(yc_te, yc_pred))
print(classification_report(yc_te, yc_pred, target_names=data.target_names))

# %% [markdown]
# ### Exercise 2.4: Bias–variance intuition

# %% [markdown]
# **Your job**: Plot train vs test MSE as a function of Ridge $\alpha$.

# %%
alphas = np.logspace(-3, 3, 15)
train_mse, test_mse = [], []
for a in alphas:
    # YOUR CODE HERE
    r = Ridge(alpha=a)
    r.fit(X_train, y_train)
    train_mse.append(mean_squared_error(y_train, r.predict(X_train)))
    test_mse.append(mean_squared_error(y_test, r.predict(X_test)))

plt.semilogx(alphas, train_mse, label="train")
plt.semilogx(alphas, test_mse, label="test")
plt.xlabel("alpha")
plt.ylabel("MSE")
plt.legend()
plt.title("Ridge regularization path")
plt.show()

# %% [markdown]
# ## Reflection (Day 2)
#
# Take a few minutes to answer in your own words:
#
# 1. What was the most important concept you practiced today (statistical learning with sklearn)?
# 2. Where did you get stuck, and how did you resolve it?
# 3. How would you explain today's material to a classmate in two sentences?
# 4. What would you like to explore further?
